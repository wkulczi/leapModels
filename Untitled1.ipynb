# %%
import keras.activations
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, BatchNormalization, Reshape, Input, InputLayer
from keras.layers.convolutional import Conv2D, MaxPooling2D
import tensorflow as tf
import os
import random
import math
import shutil

data_dir = "../train/photoPadded/maxHeightNoResize/leapCropped"


def createTestDataset(seed=None):
    filePaths = []
    for dirname, dirs, files in os.walk(data_dir):
        for filename in files:
            filePaths.append(dirname[-1] + "/" + filename)

    random.seed(seed)
    randomSelect = random.sample(filePaths, math.floor(len(filePaths) * 0.2))

    for selectedFile in randomSelect:
        shutil.move(data_dir + "/" + selectedFile, "test/" + selectedFile)

    testFileNames = []

    for dirname, dirs, files in os.walk("test/"):
        for filename in files:
            testFileNames.append(dirname[-1] + "/" + filename)

    return testFileNames


def revertData(testFileNames):
    for testFilePath in testFileNames:
        try:
            shutil.move("test/" + testFilePath, data_dir + "/" + testFilePath)
        except Exception:
            pass


# todo zbuduj prepare data funkcje, która wydzieli osobny folder ze zdjęciami do zestawu testowego
# todo dodaj callbacki(?)


def to_grey_rescaled(image):
    # img = img_to_array(image)
    # img = tf.image.rgb_to_grayscale(img)

    img = image / 255
    return img


def path_to_image(path):
    img = tf.keras.utils.load_img(path, grayscale=True)
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img / 255
    return img


image_size = (171, 171)
batch_size = 32

testFileNames = createTestDataset()

testDatagen = ImageDataGenerator(preprocessing_function=to_grey_rescaled)

test_generator = testDatagen.flow_from_directory(
    'test',
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
    color_mode='grayscale',
)

# https://www.geeksforgeeks.org/how-to-normalize-center-and-standardize-image-pixels-in-keras/
datagen = ImageDataGenerator(validation_split=0.2,
                             preprocessing_function=to_grey_rescaled)  # img/255 or use rescale=1.0/255.0

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
    color_mode='grayscale',
    # https://stackoverflow.com/questions/59439128/what-does-class-mode-parameter-in-keras-image-gen-flow-from-directory-signify
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
    color_mode='grayscale',
    # https://stackoverflow.com/questions/59439128/what-does-class-mode-parameter-in-keras-image-gen-flow-from-directory-signify
    subset='validation'
)

# czas matmę

# (N-F)/stride+1

model = Sequential()
model.add(
    Conv2D(filters=16, kernel_size=(3, 3), input_shape=(171, 171, 1), activation=keras.activations.relu,
           strides=(1, 1),
           kernel_initializer=keras.initializers.random_uniform))  # (171 + 2)-3/1+1 = 171
model.add(MaxPooling2D(pool_size=(3, 3), strides=(3, 3)))  # 171-3/3 + 1 =  57
# model.add(
#     Conv2D(filters=32, kernel_size=(3, 3), input_shape=(171, 171, 1), padding="same", activation=keras.activations.relu,
#            strides=(1, 1),
#            kernel_initializer=keras.initializers.random_uniform))  # (57 + 2)-3/1+1 = 57
model.add(Flatten())  # 57*57 = 3249
# model.add(Dense(64, activation='relu'))
# model.add(Dropout(.2))
model.add(Dense(11))

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_generator, epochs=3, validation_data=validation_generator)

test_loss, test_acc = model.evaluate(test_generator, verbose=2)
print('\nTest accuracy:', test_acc)

revertData(testFileNames)

# Test accuracy: 0.9917929172515869
# Out:
# Found 4400 images belonging to 11 classes.
# Found 14085 images belonging to 11 classes.
# Found 3515 images belonging to 11 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 169, 169, 16)      160
#
#  max_pooling2d (MaxPooling2D  (None, 56, 56, 16)       0
#  )
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 11)                551947
#
# =================================================================
# Total params: 552,107
# Trainable params: 552,107
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 441/441 [==============================] - 45s 102ms/step - loss: 0.1951 - accuracy: 0.9446 - val_loss: 0.0563 - val_accuracy: 0.9821
# Epoch 2/3
# 441/441 [==============================] - 41s 93ms/step - loss: 0.0387 - accuracy: 0.9894 - val_loss: 0.0394 - val_accuracy: 0.9883
# Epoch 3/3
# 441/441 [==============================] - 41s 92ms/step - loss: 0.0307 - accuracy: 0.9920 - val_loss: 0.0565 - val_accuracy: 0.9821
# 138/138 - 4s - loss: 0.0336 - accuracy: 0.9918 - 4s/epoch - 32ms/step
#
# Test accuracy: 0.9918181896209717

# %%
import keras.activations
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, BatchNormalization, Reshape, Input, InputLayer
from keras.layers.convolutional import Conv2D, MaxPooling2D
import tensorflow as tf
import os
import random
import math
import shutil

data_dir = "../train/photoPadded/maxHeightNoResize/leapJoints"


def createTestDataset(seed=None):
    filePaths = []
    for dirname, dirs, files in os.walk(data_dir):
        for filename in files:
            filePaths.append(dirname[-1] + "/" + filename)

    random.seed(seed)
    randomSelect = random.sample(filePaths, math.floor(len(filePaths) * 0.2))

    for selectedFile in randomSelect:
        shutil.move(data_dir + "/" + selectedFile, "test/" + selectedFile)

    testFileNames = []

    for dirname, dirs, files in os.walk("test/"):
        for filename in files:
            testFileNames.append(dirname[-1] + "/" + filename)

    return testFileNames


def revertData(testFileNames):
    for testFilePath in testFileNames:
        try:
            shutil.move("test/" + testFilePath, data_dir + "/" + testFilePath)
        except Exception:
            pass


# todo zbuduj prepare data funkcje, która wydzieli osobny folder ze zdjęciami do zestawu testowego
# todo dodaj callbacki(?)


def rescale_image(image):
    # img = img_to_array(image)
    # img = tf.image.rgb_to_grayscale(img)

    img = image / 255
    return img


def path_to_image(path):
    img = tf.keras.utils.load_img(path)
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img / 255
    return img


image_size = (171, 171)
batch_size = 32

testFileNames = createTestDataset()

testDatagen = ImageDataGenerator(preprocessing_function=rescale_image)

test_generator = testDatagen.flow_from_directory(
    'test',
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
)

# https://www.geeksforgeeks.org/how-to-normalize-center-and-standardize-image-pixels-in-keras/
datagen = ImageDataGenerator(validation_split=0.2,
                             preprocessing_function=rescale_image)  # img/255 or use rescale=1.0/255.0

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
    # https://stackoverflow.com/questions/59439128/what-does-class-mode-parameter-in-keras-image-gen-flow-from-directory-signify
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
    # https://stackoverflow.com/questions/59439128/what-does-class-mode-parameter-in-keras-image-gen-flow-from-directory-signify
    subset='validation'
)

# czas matmę

# (N-F)/stride+1

model = Sequential()
model.add(
    Conv2D(filters=16, kernel_size=(3, 3), input_shape=(171, 171, 3), activation=keras.activations.relu,
           strides=(1, 1),
           kernel_initializer=keras.initializers.random_uniform))  # (171 + 2)-3/1+1 = 171
model.add(MaxPooling2D(pool_size=(3, 3), strides=(3, 3)))  # 171-3/3 + 1 =  57
# model.add(
#     Conv2D(filters=32, kernel_size=(3, 3), input_shape=(171, 171, 1), padding="same", activation=keras.activations.relu,
#            strides=(1, 1),
#            kernel_initializer=keras.initializers.random_uniform))  # (57 + 2)-3/1+1 = 57
model.add(Flatten())  # 57*57 = 3249
# model.add(Dense(64, activation='relu'))
# model.add(Dropout(.2))
model.add(Dense(11))

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_generator, epochs=3, validation_data=validation_generator)

test_loss, test_acc = model.evaluate(test_generator, verbose=2)
print('\nTest accuracy:', test_acc)

revertData(testFileNames)

# Test accuracy: 0.9917929172515869
# Out:
# Found 4400 images belonging to 11 classes.
# Found 14084 images belonging to 11 classes.
# Found 3516 images belonging to 11 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 169, 169, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 56, 56, 16)       0
#  )
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 11)                551947
#
# =================================================================
# Total params: 552,395
# Trainable params: 552,395
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 441/441 [==============================] - 46s 103ms/step - loss: 0.1296 - accuracy: 0.9737 - val_loss: 0.0552 - val_accuracy: 0.9809
# Epoch 2/3
# 441/441 [==============================] - 45s 102ms/step - loss: 0.0205 - accuracy: 0.9937 - val_loss: 0.0546 - val_accuracy: 0.9846
# Epoch 3/3
# 441/441 [==============================] - 45s 101ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.0402 - val_accuracy: 0.9881
# 138/138 - 5s - loss: 0.0287 - accuracy: 0.9914 - 5s/epoch - 39ms/step
#
# Test accuracy: 0.9913636445999146

# %%
filePaths = []
for dirname, dirs, files in os.walk(data_dir):
    for filename in files:
        filePaths.append(dirname[-1] + "/" + filename)

randomSelect = random.sample(filePaths, math.floor(len(filePaths) * 0.2))

for selectedFile in randomSelect:
    shutil.move(data_dir + "/" + selectedFile, "test/" + selectedFile)

testFileNames = []

for dirname, dirs, files in os.walk("test/"):
    for filename in files:
        testFileNames.append(dirname[-1] + "/" + filename)

# %%
for testFilePath in testFileNames:
    try:
        shutil.move("test/" + testFilePath, data_dir +"/"+ testFilePath)            
    except Exception: 
        pass

# %%
import keras.activations
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, BatchNormalization, Reshape, Input, InputLayer
from keras.layers.convolutional import Conv2D, MaxPooling2D
import tensorflow as tf
import os
import random
import math
import shutil

data_dir = "../train/photoPadded/maxHeightNoResize/mpPhotos"


def createTestDataset(seed=None):
    filePaths = []
    for dirname, dirs, files in os.walk(data_dir):
        for filename in files:
            filePaths.append(dirname[-1] + "/" + filename)

    random.seed(seed)
    randomSelect = random.sample(filePaths, math.floor(len(filePaths) * 0.2))

    for selectedFile in randomSelect:
        shutil.move(data_dir + "/" + selectedFile, "test/" + selectedFile)

    testFileNames = []

    for dirname, dirs, files in os.walk("test/"):
        for filename in files:
            testFileNames.append(dirname[-1] + "/" + filename)

    return testFileNames


def revertData(testFileNames):
    for testFilePath in testFileNames:
        try:
            shutil.move("test/" + testFilePath, data_dir + "/" + testFilePath)
        except Exception:
            pass


# todo zbuduj prepare data funkcje, która wydzieli osobny folder ze zdjęciami do zestawu testowego
# todo dodaj callbacki(?)


def rescale_image(image):
    # img = img_to_array(image)
    # img = tf.image.rgb_to_grayscale(img)

    img = image / 255
    return img


def path_to_image(path):
    img = tf.keras.utils.load_img(path)
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img / 255
    return img


image_size = (171, 171)
batch_size = 32

testFileNames = createTestDataset()

testDatagen = ImageDataGenerator(preprocessing_function=rescale_image)

test_generator = testDatagen.flow_from_directory(
    'test',
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
)

# https://www.geeksforgeeks.org/how-to-normalize-center-and-standardize-image-pixels-in-keras/
datagen = ImageDataGenerator(validation_split=0.2,
                             preprocessing_function=rescale_image)  # img/255 or use rescale=1.0/255.0

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
    # https://stackoverflow.com/questions/59439128/what-does-class-mode-parameter-in-keras-image-gen-flow-from-directory-signify
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
    # https://stackoverflow.com/questions/59439128/what-does-class-mode-parameter-in-keras-image-gen-flow-from-directory-signify
    subset='validation'
)

# czas matmę

# (N-F)/stride+1

model = Sequential()
model.add(
    Conv2D(filters=16, kernel_size=(3, 3), input_shape=(171, 171, 3), activation=keras.activations.relu,
           strides=(1, 1),
           kernel_initializer=keras.initializers.random_uniform))  # (171 + 2)-3/1+1 = 171
model.add(MaxPooling2D(pool_size=(3, 3), strides=(3, 3)))  # 171-3/3 + 1 =  57
# model.add(
#     Conv2D(filters=32, kernel_size=(3, 3), input_shape=(171, 171, 1), padding="same", activation=keras.activations.relu,
#            strides=(1, 1),
#            kernel_initializer=keras.initializers.random_uniform))  # (57 + 2)-3/1+1 = 57
model.add(Flatten())  # 57*57 = 3249
# model.add(Dense(64, activation='relu'))
# model.add(Dropout(.2))
model.add(Dense(11))

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_generator, epochs=3, validation_data=validation_generator)

test_loss, test_acc = model.evaluate(test_generator, verbose=2)
print('\nTest accuracy:', test_acc)

revertData(testFileNames)

# Test accuracy: 0.9917929172515869
# Out:
# Found 4400 images belonging to 11 classes.
# Found 14086 images belonging to 11 classes.
# Found 3514 images belonging to 11 classes.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 169, 169, 16)      448
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 16)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 50176)             0
#
#  dense_1 (Dense)             (None, 11)                551947
#
# =================================================================
# Total params: 552,395
# Trainable params: 552,395
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 441/441 [==============================] - 46s 104ms/step - loss: 0.1327 - accuracy: 0.9686 - val_loss: 0.0696 - val_accuracy: 0.9769
# Epoch 2/3
# 441/441 [==============================] - 45s 102ms/step - loss: 0.0278 - accuracy: 0.9916 - val_loss: 0.0781 - val_accuracy: 0.9784
# Epoch 3/3
# 441/441 [==============================] - 45s 102ms/step - loss: 0.0187 - accuracy: 0.9939 - val_loss: 0.0777 - val_accuracy: 0.9784
# 138/138 - 5s - loss: 0.0301 - accuracy: 0.9920 - 5s/epoch - 39ms/step
#
# Test accuracy: 0.9920454621315002

# %%
import keras.activations
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, BatchNormalization, Reshape, Input, InputLayer
from keras.layers.convolutional import Conv2D, MaxPooling2D
import tensorflow as tf
import os
import random
import math
import shutil

data_dir = "../train/photoRaw/leapCropped"


def createTestDataset(seed=None):
    filePaths = []
    for dirname, dirs, files in os.walk(data_dir):
        for filename in files:
            filePaths.append(dirname[-1] + "/" + filename)

    random.seed(seed)
    randomSelect = random.sample(filePaths, math.floor(len(filePaths) * 0.2))

    for selectedFile in randomSelect:
        shutil.move(data_dir + "/" + selectedFile, "test/" + selectedFile)

    testFileNames = []

    for dirname, dirs, files in os.walk("test/"):
        for filename in files:
            testFileNames.append(dirname[-1] + "/" + filename)

    return testFileNames


def revertData(testFileNames):
    for testFilePath in testFileNames:
        try:
            shutil.move("test/" + testFilePath, data_dir + "/" + testFilePath)
        except Exception:
            pass


# todo zbuduj prepare data funkcje, która wydzieli osobny folder ze zdjęciami do zestawu testowego
# todo dodaj callbacki(?)


def rescale_image(image):
    # img = img_to_array(image)
    # img = tf.image.rgb_to_grayscale(img)

    img = image / 255
    return img


def path_to_image(path):
    img = tf.keras.utils.load_img(path)
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img / 255
    return img


image_size = (64, 64)
batch_size = 32

testFileNames = createTestDataset()

testDatagen = ImageDataGenerator(preprocessing_function=rescale_image)

test_generator = testDatagen.flow_from_directory(
    'test',
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
    color_mode='grayscale',
)

# https://www.geeksforgeeks.org/how-to-normalize-center-and-standardize-image-pixels-in-keras/
datagen = ImageDataGenerator(validation_split=0.2,
                             preprocessing_function=rescale_image)  # img/255 or use rescale=1.0/255.0

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
    color_mode='grayscale',
    # https://stackoverflow.com/questions/59439128/what-does-class-mode-parameter-in-keras-image-gen-flow-from-directory-signify
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="sparse",
    color_mode='grayscale',
    # https://stackoverflow.com/questions/59439128/what-does-class-mode-parameter-in-keras-image-gen-flow-from-directory-signify
    subset='validation'
)

# czas matmę

# (N-F)/stride+1

model = Sequential()
model.add(
    Conv2D(filters=16, kernel_size=(3, 3), input_shape=(64, 64, 1), activation=keras.activations.relu,
           strides=(1, 1),
           kernel_initializer=keras.initializers.random_uniform))  # (171 + 2)-3/1+1 = 171
model.add(MaxPooling2D(pool_size=(3, 3), strides=(3, 3)))  # 171-3/3 + 1 =  57
# model.add(
#     Conv2D(filters=32, kernel_size=(3, 3), input_shape=(171, 171, 1), padding="same", activation=keras.activations.relu,
#            strides=(1, 1),
#            kernel_initializer=keras.initializers.random_uniform))  # (57 + 2)-3/1+1 = 57
model.add(Flatten())  # 57*57 = 3249
# model.add(Dense(64, activation='relu'))
# model.add(Dropout(.2))
model.add(Dense(11))

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_generator, epochs=3, validation_data=validation_generator)

test_loss, test_acc = model.evaluate(test_generator, verbose=2)
print('\nTest accuracy:', test_acc)

revertData(testFileNames)

# Test accuracy: 0.9917929172515869
# Out:
# Found 4400 images belonging to 11 classes.
# Found 14085 images belonging to 11 classes.
# Found 3515 images belonging to 11 classes.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 62, 62, 16)        160
#
#  max_pooling2d_4 (MaxPooling  (None, 20, 20, 16)       0
#  2D)
#
#  flatten_4 (Flatten)         (None, 6400)              0
#
#  dense_4 (Dense)             (None, 11)                70411
#
# =================================================================
# Total params: 70,571
# Trainable params: 70,571
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 441/441 [==============================] - 9s 20ms/step - loss: 0.2648 - accuracy: 0.9351 - val_loss: 0.0527 - val_accuracy: 0.9849
# Epoch 2/3
# 441/441 [==============================] - 7s 16ms/step - loss: 0.0402 - accuracy: 0.9884 - val_loss: 0.0491 - val_accuracy: 0.9835
# Epoch 3/3
# 441/441 [==============================] - 7s 16ms/step - loss: 0.0267 - accuracy: 0.9927 - val_loss: 0.0488 - val_accuracy: 0.9849
# 138/138 - 2s - loss: 0.0334 - accuracy: 0.9898 - 2s/epoch - 16ms/step
#
# Test accuracy: 0.9897727370262146
